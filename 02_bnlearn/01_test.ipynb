# %%
import bnlearn as bn
df = bn.import_example()
model = bn.structure_learning.fit(df)
bn.plot(model, node_color='#8A0707')
# Out:
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model
# {'fig': <Figure size 1500x1000 with 1 Axes>,
#  'ax': <Figure size 1500x1000 with 1 Axes>,
#  'pos': {'Cloudy': array([-0.28906071, -1.        ]),
#   'Sprinkler': array([-0.18256683,  0.01712998]),
#   'Rain': array([0.23232469, 0.01900197]),
#   'Wet_Grass': array([0.23930285, 0.96386805])},
#  'G': <networkx.classes.digraph.DiGraph at 0x105dd8550>,
#  'node_properties': {'Cloudy': {'node_color': '#1f456e', 'node_size': 800},
#   'Sprinkler': {'node_color': '#1f456e', 'node_size': 800},
#   'Rain': {'node_color': '#1f456e', 'node_size': 800},
#   'Wet_Grass': {'node_color': '#1f456e', 'node_size': 800}},
#  'edge_properties': {('Sprinkler', 'Cloudy'): {'color': '#000000',
#    'weight': 1},
# ...
